# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed
import torch
import random

# %%
gr = []
from database.arangodb import DatabaseConnector
gdb = DatabaseConnector()
db = gdb.connect_db('prodemo')
query = 'FOR doc IN  s4_llm_output RETURN doc'
cursor = db.aql.execute(query)
for line in cursor:
    gr.append(line['candidate'])

# %%
print(gr)

# %%
model = AutoModelForCausalLM.from_pretrained("facebook/opt-2.7b", cache_dir="opt27_model/", torch_dtype=torch.float16).cuda()
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-2.7b", cache_dir="opt27_model/", use_fast=False)

# %%
for para in gr:
    for event in para.split('.'):
        if event != '':
            set_seed(64)
            prompt = '''
            The woman is standing in front of a car window => people
            To the left of the bed is a table with a white vase on it => objects
            The room is dark and the only light is coming from a lamp on a table next to the couch => objects
            Man and woman are sitting at a dinner table with a man in a suit and tie => people
            The room is dimly lit with colored lights => objects
            She is looking at the camera and smiling => people
            The bush of pink flowers is in full bloom => objects
            {} => '''.format(event) 
            set_seed(64)
            input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
            generated_ids = model.generate(input_ids, do_sample=True, max_length=250)
            type_of_image = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
            print("Event: ", event)
            #print(type_of_image[0])
            print(type_of_image[0].split(event)[1].split('\n')[0])
# Out:
# Event:  The woman is standing in a room with a white background
#  =>  people
# Event:   She is wearing a white dress with a floral print on it
#  =>  people
# Event:   She is looking at the camera and smiling
#  => people
# Event:  The woman in the image is young and slender
#  =>  people
# Event:   She is sitting on a white bed with her hands on her chest
#  =>  people
# Event:   To the left of the bed is a table with a white vase on it
#  => objects
# Event:  She is wearing a white, flowy dress
#  =>  people
# Event:   The woman has her hair pulled back in a low ponytail
#  =>  people
# Event:   She is wearing sunglasses
#  =>  people
# Event:   The leaves of the palm trees are green
#  =>  objects
# Event:  A woman in a white sundress and sunglasses is standing in front of a bush of pink flowers
#  =>  people
# Event:   The woman has one hand on her hip
#  =>  people
# Event:   The bush of pink flowers is in full bloom
#  => objects
# Event:  The image is set in a bedroom at night
#  =>  people
# Event:   A woman in a white nightgown is lying in bed asleep
#  =>  people
# Event:   A lamp on the wall behind him casts a soft light over the room
#  =>  people
# Event:  The setting of this image appears to be a dimly lit or dark room
#  =>  people
# Event:   There is a man laying on a couch with his eyes closed
#  =>  people
# Event:   She is also wearing a white t-shirt and blue jeans
#  =>  people
# Event:  The room is dark and the only light is coming from a lamp on a table next to the couch
#  => objects
# Event:   The man is sleeping and has a pillow under his head
#  =>  people
# Event:   He is wearing a white shirt and black pants
#  =>  people
# Event:  The image is of a small town with a church in the center
#  =>  people
# Event:   The church is white with a steeple
#  =>  people
# Event:   Some of the houses have picket fences
#  =>  people
# Event:  This image is of a line of shoes that are hanging from a wire
#  =>  people
# Event:   There are shoes for both men and women
#  =>  people
# Event:   The background is of a small town
#  =>  people
# Event:   There are houses and trees
#  =>  people
# Event:  A well-dressed man is sitting at a table in a banquet hall
#  =>  people
# Event:   He is talking to a woman who is also well-dressed
#  =>  people
# Event:   Behind the man and woman is a big window
#  =>  people
# Event:  Both are adult Caucasian individuals
#  =>  people
# Event:   He has a red tie
#  =>  people
# Event:   Both individuals are holding wine glasses and appear to be in the midst of a conversation
#  =>  people
# Event:  A man and woman are sitting at a dinner table with a man in a suit and tie
#  =>  people
# Event:   He is also looking at the man and woman
#  =>  people
# Event:   There are other people sitting at the table, but they are not in the image
#  =>  Not in frame
# Event:  The restaurant is busy with people sitting at tables and standing around
#  =>  people
# Event:   The man and woman are talking to each other
#  =>  people
# Event:   The woman is smiling
#  =>  people
# Event:   The woman is wearing a red dress
#  =>  people
# Event:  A man wearing a blue jacket and red shirt is sitting on the ground
#  =>  people
# Event:   He is looking to the left of the frame
#  =>  people
# Event:   There are trees and vegetation surrounding him
#  =>  people
# Event:  A man is standing in the woods
#  =>  people
# Event:   He is wearing a black hat and black boots
#  =>  people
# Event:   He has a long beard
#  =>  people
# Event:   There is a green plant in the background
#  =>  people
# Event:  He is facing the camera
#  =>  people
# Event:   There are rocks and trees on both sides of the river
#  =>  people
# Event:   The water is flowing around his legs
#  =>????
# Event:  A man and woman are standing in a grand entrance hall
#  =>  people
# Event:   The man is wearing a military uniform, and the woman is wearing a red dress
#  =>  people
# Event:   They are both smiling
#  =>  people
# Event:  The man and woman are kissing in front of a large crowd of people
#  =>  people
# Event:   The man is wearing a suit and the woman is wearing a dress
#  =>  people
# Event:   The man has his hand on the woman's waist
#  =>  people
# Event:  Both men are wearing dark colored suits
#  =>  people
# Event:   The man with the hat appears to be talking to the man without a hat
#  =>????
# Event:   There are people walking by them in the background
#  =>  people
# Event:  Two men shake hands in front of a large door
#  =>  people
# Event:   Both men are wearing suits
#  =>  people
# Event:   There is a woman standing behind the man with the hat
#  =>  people
# Event:   She is also wearing a suit
#  =>  people
# Event:  A man and woman are on a stage
#  =>  people
# Event:   The woman is wearing a white dress
#  =>  people
# Event:   They are both looking at the crowd
#  =>  people
# Event:  The people appear to be of different ethnicities, and they are all wearing different clothes
#  =>  people
# Event:   There is a man in the foreground who is wearing a white shirt and dark pants
#  =>  people
# Event:   He is also wearing a yarmulke, which is a Jewish skullcap
#  =>????
# Event:  He has a black yarmulke on his head
#  =>????
# Event:   He is frowning
#  =>  people
# Event:   The building behind him is brick
#  =>  people
# Event:  A group of people are walking down a city street
#  =>  people
# Event:   Most of the people appear to be of Jewish descent, as they are wearing yarmulkes
#  =>  people
# Event:   One man in the group is jogging, while the others appear to be walking and talking
#  =>  people
# Event:  A man is sitting on a bench outside a building
#  =>  people
# Event:   He is wearing a yarmulke and has a frown on his face
#  =>  people
# Event:   He looks like he is waiting for someone
#  =>????
# Event:  The people are of different ethnicity and are wearing different clothes
#  =>  people
# Event:   The person in the front is wearing a white shirt and dark pants
#  =>  people
# Event:   The person behind him is wearing a blue shirt and light pants
#  =>  people
# Event:   She has dark hair and is carrying a black bag
#  =>  people
# Event:   The person in the back is wearing a white shirt and dark pants
#  =>  people
# Event:   He has dark hair and is carrying a white bag
#  =>  people
# Event:  The man is bald
#  =>  women
# Event:   The man is wearing a yarmulke
#  =>????
# Event:   The man is frowning
#  =>  people
# Event:  The computer screen is white
#  =>  people
# Event:   On the right side of the screen is a green button that reads "Download
#  =>???????" => people
# Event:  " On the left side of the screen is a red X
#  =>  This
# Event:  There is a text box in the middle of the screen
#  =>????
# Event:   The text box is white
#  =>  people
# Event:   The text box is for writing a song
#  =>????
# Event:   The screen is for a music studio
#  =>????
# Event:   The person is writing a song
#  =>????
# Event:   The person is sitting in a chair
#  =>  people
# Event:  The image is a computer screen
#  =>  computer
# Event:   In the search bar, it says "How to make a toy shop
#  =>???????" =>???
# Event:  " The background of the screen is white
#  =>  people
# Event:  The woman is sitting on a pink couch with a white pillow in her lap
#  =>  objects
# Event:   She is wearing a white shirt and pink pants
#  =>  people
# Event:   There is a cat sitting on the couch next to the woman
#  =>????
# Event:  A girl is sitting on a white couch
#  =>  people
# Event:   The girl is small and is wearing a pink dress
#  =>  people
# Event:   The girl has black hair that is in a ponytail
#  =>  people
# Event:   The girl is reading a book
#  =>  people
# Event:  A woman is standing in front of a television set that is attached to a metal pole
#  =>  people
# Event:   The screen is showing the words "Do different versions
#  =>???????" =>???
# Event:  " The woman is wearing a white shirt, blue jeans, and sneakers
#  =>  people
# Event:  The man is looking at the television screen with a caption that reads, "Couch to 5K
#  =>???????" => people
# Event:  " The man is standing on a staircase
#  =>  people
# Event:   There is a handrail on the staircase
#  =>  people
# Event:   The man is wearing blue jeans and a white shirt
#  =>  people
# Event:  A young child is sitting on a brown couch with her mouth wide open
#  =>????
# Event:   She has brown eyes and black hair
#  =>  people
# Event:   The child's arms and legs are crossed
#  =>  people
# Event:  A small girl is pictured on a stage
#  =>  people
# Event:   She has a microphone in her hand and is singing into it
#  =>????
# Event:   She is wearing a pink dress
#  =>  people
# Event:  A woman is sitting on a red chair
#  =>  people
# Event:   She is wearing a black dress
#  =>  people
# Event:   She has her hands in her lap
#  =>  people
# Event:   She has a microphone in her right hand
#  =>????
# Event:  The stage is red and the chairs are also red
#  =>  objects
# Event:   The people are all wearing black
#  =>  people
# Event:   They are sitting in a semi-circle
#  =>  people
# Event:   There is a microphone in front of each person
#  =>  people
# Event:  A little girl is standing on a stage
#  =>????
# Event:     She is singing into a microphone
#  =>  sound
# Event:     She is wearing a red dress
#  =>  people
# Event:     She is smiling
#  =>  people
# Event:  Both men are wearing all black
#  =>  people
# Event:   One man has a microphone in his hand
#  =>  sound
# Event:   He has a beard and mustache
#  =>  people
# Event:   He has a tattoo on his arm
#  =>  people
# Event:  A little girl is standing on a stage singing into a microphone
#  =>  people
# Event:   She is wearing a pink dress and has a bow in her hair
#  =>  people
# Event:   She is standing in front of a microphone stand
#  =>  sound
# Event:  A young woman is standing in front of a television that is playing a video
#  =>  people
# Event:   The video has the words "Do different versions" on the screen
#  =>????
# Event:   She has on a blue shirt and blue jeans
#  =>  people
# Event:  A man is sitting in the driver's seat of car
#  =>  people
# Event:   He has his hands on the steering wheel and is looking to the side
#  =>  people
# Event:   The man is wearing a hat and a jacket
#  =>  people
# Event:  The room is dark, with only a small light on the table
#  =>  people
# Event:   The family is eating a meal
#  =>  people
# Event:   All four family members have plates of food in front of them
#  =>  people
# Event:  The scene is set in a small, quaint dining room
#  =>  people
# Event:   A plate of food is in front of the man, and he is eating a meal
#  =>  people
# Event:   The man is balding, and he has a mustache
#  =>  people
# Event:  There is a table with people sitting around it
#  =>  people
# Event:   There are plates of food on the table and cups of coffee
#  =>  people
# Event:   The people are talking and laughing
#  =>  people
# Event:  A man is sitting at a dinner table with a plate of food in front of him
#  =>  people
# Event:   The man has a fork in his right hand and a knife in his left hand
#  =>  people
# Event:   He is looking at the food with a look of disgust on his face
#  =>  people
# Event:  A woman with dark hair is sitting at a table
#  =>  people
# Event:   She has a fork in her right hand
#  =>  people
# Event:   The woman is looking at the food
#  =>  people
# Event:  A woman is sitting at a wooden table in a dining room
#  =>  people
# Event:   In front of her is a white plate with food on it
#  =>  food
# Event:   On the table there is a white tablecloth and a vase with flowers
#  =>  objects
# Event:  A woman sitting at a table with a plate of food
#  =>  people
# Event:   The plate has eggs, bacon, and toast on it
#  =>  people
# Event:   The woman is smiling and has a cup of coffee in front of her
#  =>  people
# Event:  Eleven people are standing in a room
#  =>  people
# Event:   They are all looking up at something
#  =>????
# Event:   There is a light fixture on the ceiling
#  =>  people
# Event:  The room is dimly lit with colored lights
#  => objects
# Event:   The people are in the center of the room and are dancing close together
#  =>  people
# Event:   Some of the people have their arms in the air
#  =>  people
# Event:  The woman is on the floor
#  =>  people
# Event:   She has a red mark on her neck
#  =>????
# Event:   He is wearing a red shirt
#  =>  people
# Event:   There is a blue mark on his neck
#  =>????
# Event:  A man is sitting on the floor playing with a white dog
#  =>  people
# Event:   The man is wearing a red sweater, blue jeans, and brown shoes
#  =>  people
# Event:   His hair is dark and short
#  =>  people
# Event:  The woman is upset
#  =>  people
# Event:   She is lying on the ground with her head in her hands
#  =>????
# Event:   She has long hair that is brown
#  =>  people
# Event:   She is wearing a white dress
#  =>  people
# Event:  The man and woman are sitting on a red couch
#  =>  people
# Event:   They are both looking at each other and talking
#  =>  people
# Event:   There is a window behind the couch
#  =>  people
# Event:  The image is of a young man, who looks to be a high school student, sitting on the floor of a locker room
#  =>  people
# Event:   He is wearing a red vest, white shirt, and blue jeans
#  =>  people
# Event:   His backpack is next to him, and he has his arms crossed
#  =>  people
# Event:  The image is of a man, who is probably in his twenties, standing in front of a group of people
#  =>  people
# Event:   He is wearing a red jacket and has his hands raised in the air
#  =>  people
# Event:   He has a small beard and mustache
#  =>  people
# Event:  The man is holding up his hand in a gesture
#  =>  people
# Event:   He is wearing a red jacket
#  =>  people
# Event:   On his head, he wears headphones
#  =>  people
# Event:   The headphones are black
#  =>  people
# Event:  A man is sleeping on the floor in a foetal position
#  =>????
# Event:   His head is in his hands and his face is hidden
#  =>????
# Event:   There is a pillow next to him
#  =>  people
# Event:  A group of people are gathered in a room while a woman dances in the center
#  =>  people
# Event:   The woman is topless and wearing a green and blue skirt that is billowing around her as she dances
#  =>  people
# Event:   Her long brown hair is cascading down her back
#  =>  people
# Event:   The people around her are clapping and cheering
#  =>  people
# Event:   There is a man in a blue shirt standing behind her with his arms raised
#  =>????
# Event:  The woman is holding a fork in her hand
#  =>  people
# Event:   The woman has a wedding ring on her finger
#  =>  people
# Event:   The woman is looking down at her food
#  =>  people
# Event:  He has a phone in his hand and is looking down at it
#  =>  people
# Event:   He is in a dark room
#  =>  people
# Event:   There is a light above him
#  =>????
# Event:  There is a man wearing a white shirt and a red tie
#  =>  people
# Event:   The man has a light shining on his face from the left
#  =>  people
# Event:   The man has his eyes closed and his mouth open
#  =>????
# Event:  The TV has a sign that reads: "No TV before 8:00 am
#  =>  people
# Event:  " The man has a double chin and sideburns
#  =>  people
# Event:   He has a smirk on his face
#  =>  people
# Event:  A computer screen is displayed with instructions on how to download a coupon
#  =>  instructions
# Event:     The text is displayed in a list format
#  =>  words
# Event:     The first item on the list is "Go to the website
#  =>???????" =>???
# Event:  "
#  =>   'Pomona.'
# Event:  On a computer screen, there is a document open with the title "How to Write a Song
#  =>???????" =>???
# Event:  " Some of the tips are: "Find a melody you like and hum it to yourself," "Start with the chorus," and "Think about what the song is about
#  => ,'"says Meehan, who recently received the National
# Event:  " The document is in a sans serif font, and is black and white
#  =>  people
# Event:  There is a computer screen with a picture of a person on the screen
#  =>  people
# Event:   The person is looking at the camera
#  =>  people
# Event:   The white bar has the word "Google" in black letters
#  =>  objects

# %%
event_ = ["a person plays a video game centered around ice age the movie","men are playing sports",
"girl with wings dances and sings the ole mcdonald song","person is looking down at a paper",
"has hands in pockets", "person is taking a tiny spoon and scooping up a heap of caviar",
"person is in the background conversing with others in the room",
"person is full of wounds and is standing beside his taxi in the middle of a \
street and giving instruction between the trucks that are parked on the street",
"person is standing on the table spraying a hose","person is crossing the busy street and watching a taxi speed off",
"person is sitting on a hospital bed and he is afraid of",
"person x is meanly looking at person y like he is about to throw a punch",
"person x is in uniform signaling for the life boat to lower and looking at person y in disgust",
"person sits in the lifeboat with his eyes closed looking ashamed and relieved",
"doctor examining person on a table",
"person x and person y embrace one another",
"at a fancy party pesron is trying to talk to the pretty woman in front of him"]

events_and_intents = []
for event in event_:
    set_seed(64)
    prompt = '''generate intent of action:
    person is facing the crowd while holding a microphone because he wants => to make a public statement.
    pesron is sitting at the bar in a sexy dress and waiting for someone because she wants => to flirt with a man.
    person is an officer that has handcuffed a citizen to himself because he wants => to arrest the citizen.
    person is carrying her meal to her table because she wants => to sit down to eat.
    {} because he or she wants => '''.format(event)
    print("EVENT: ",event)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
    intents = []
    for i in range(5):
        
        generated_ids = model.generate(input_ids, do_sample=True, max_length=160)
        intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        #print(intent)
        intent = intent[0].split(event)[1].replace("\n",".").split(".")[0].split("=>")
        if len(intent) > 1:
            intent = intent[1]
        else:
            continue
        intents.append(intent.lstrip())
        print("    with the intent", intent.lstrip())
    events_and_intents.append((event, intents))
print(events_and_intents)

# %%
event_ = ["a person plays a video game centered around ice age the movie","men are playing sports","girl with wings dances and sings the ole mcdonald song","person is looking down at a paper", "has hands in pockets", "person is taking a tiny spoon and scooping up a heap of caviar",
"person is in the background conversing with others in the room", \
"person is full of wounds and is standing beside his taxi in the middle of a \
street and giving instruction between the trucks that are parked on the street",
"person is standing on the table spraying a hose","person is crossing the busy street and watching a taxi speed off",\
"person is sitting on a hospital bed and he is afraid of", "person x is meanly looking at person y like he is about to throw a punch",
"person x is in uniform signaling for the life boat to lower and looking at person y in disgust",
"person sits in the lifeboat with his eyes closed looking ashamed and relieved",
"doctor examining person on a table",
"person x and person y embrace one another",
"at a fancy party pesron is trying to talk to the pretty woman in front of him"]

events_and_intents = []
for event in event_:
    set_seed(64)
    prompt = '''generate intent of action:
    person is facing the crowd while holding a microphone in order to => make a public statement.
    pesron is sitting at the bar in a sexy dress and waiting for someone in order to => flirt with a man.
    person is an officer that has handcuffed a citizen to himself in order to => arrest the citizen.
    person is carrying her meal to her table in order to => sit down to eat.
    {} in order to => '''.format(event)
    print("EVENT: ",event)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
    intents = []
    for i in range(10):
        
        generated_ids = model.generate(input_ids, do_sample=True, max_length=160)
        intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        #print("1    --->",intent)
        intent = intent[0].split(event)[1].replace("\n",".").split(".")[0].split("=>")
        
        if len(intent) > 1:
            intent = intent[1]
        else:
            continue
        intents.append(intent.lstrip())
        print("2    --->",intent.lstrip())
    events_and_intents.append((event, intents))
print(events_and_intents)

# %%
def get_prompy(query):
    #random.randrange(len(gr)-1)
    ev1 = gr[random.randrange(len(gr)-1)]
    ev2 = gr[random.randrange(len(gr)-1)]
    ev3 = gr[random.randrange(len(gr)-1)]
    ev4 = gr[random.randrange(len(gr)-1)]
    ev5 = gr[random.randrange(len(gr)-1)]
    ev6 = gr[random.randrange(len(gr)-1)]
   
    fsi=[ev1[0],ev1[1],ev2[0],ev2[1],ev3[0],ev3[1],ev4[0],ev4[1],ev5[0],ev5[1],ev6[0],ev6[1], query]
    prompt = '''generate intent of action:
        {} because he/she wants => {}.
        {} because he/she wants => {}.
        {} because he/she wants => {}.
        {} because he/she wants => {}.
        {} because he/she wants => {}.
        {} because he/she wants => {}.
        {} because he/she wants => '''.format(*fsi)
    return(prompt)

# %%
events_and_intents = []
for event_ in gr:
    event = event_[0]
    prompt = get_prompy(event)
    set_seed(64)
    print("EVENT: ",event)
    
    print(prompt)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
    intents = []
    for i in range(5):
        
        generated_ids = model.generate(input_ids, do_sample=True, max_length=300)
        intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        #print("1    --->",intent)
        intent = intent[0].split(event)[1].replace("\n",".").split(".")[0].split("=>")
        
        if len(intent) > 1:
            intent = intent[1]
        else:
            continue
        intents.append(intent.lstrip())
        print("2    --->",intent.lstrip())
    events_and_intents.append({"db_id":event_[3],"movie":event_[2], "caption":event, "intention":intents})
    #print(events_and_intents)
    #input()

# %%
event_ = ["a person plays a video game centered around ice age the movie","men are playing sports","girl with wings dances and sings the ole mcdonald song","person is looking down at a paper", "has hands in pockets", "person is taking a tiny spoon and scooping up a heap of caviar",
"person is in the background conversing with others in the room", \
"person is full of wounds and is standing beside his taxi in the middle of a \
street and giving instruction between the trucks that are parked on the street",
"person is standing on the table spraying a hose","person is crossing the busy street and watching a taxi speed off",\
"person is sitting on a hospital bed and he is afraid of", "person x is meanly looking at person y like he is about to throw a punch",
"person x is in uniform signaling for the life boat to lower and looking at person y in disgust",
"person sits in the lifeboat with his eyes closed looking ashamed and relieved",
"doctor examining person on a table",
"person x and person y embrace one another",
"at a fancy party pesron is trying to talk to the pretty woman in front of him"]

events_and_intents = []
for event in event_:
    set_seed(64)
    prompt = '''generate intent of action:
    person is facing the crowd while holding a microphone with intent to => make a public statement.
    pesron is sitting at the bar in a sexy dress and waiting for someone with intent to => flirt with a man.
    person is an officer that has handcuffed a citizen to himself with intent to => arrest the citizen.
    person is carrying her meal to her table with intent to => sit down to eat.
    {} with intent to => '''.format(event)
    print("EVENT: ",event)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
    intents = []
    for i in range(10):
        
        generated_ids = model.generate(input_ids, do_sample=True, max_length=160)
        intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        #print("1    --->",intent)
        intent = intent[0].split(event)[1].replace("\n",".").split(".")[0].split("=>")
        
        if len(intent) > 1:
            intent = intent[1]
        else:
            continue
        intents.append(intent.lstrip())
        print("2    --->",intent.lstrip())
    events_and_intents.append((event, intents))
print(events_and_intents)

# %%
event_ = ["a person plays a video game centered around ice age the movie","men are playing sports","girl with wings dances and sings the ole mcdonald song","person is looking down at a paper", "has hands in pockets", "person is taking a tiny spoon and scooping up a heap of caviar",
"person is in the background conversing with others in the room", \
"person is full of wounds and is standing beside his taxi in the middle of a \
street and giving instruction between the trucks that are parked on the street",
"person is standing on the table spraying a hose","person is crossing the busy street and watching a taxi speed off",\
"person is sitting on a hospital bed and he is afraid of", "person x is meanly looking at person y like he is about to throw a punch",
"person x is in uniform signaling for the life boat to lower and looking at person y in disgust",
"person sits in the lifeboat with his eyes closed looking ashamed and relieved",
"doctor examining person on a table",
"person x and person y embrace one another",
"at a fancy party pesron is trying to talk to the pretty woman in front of him"]

events_and_intents = []
for event in event_:
    set_seed(64)
    prompt = '''predict effect of action:
    person is facing the crowd while holding a microphone, as a result  => the public will engoy him speak.
    pesron is sitting at the bar in a sexy dress and waiting for someone, as a result => she will attract the attention of men.
    person is an officer that has handcuffed a citizen to himself, as a result =>  the citizen will be arrested and convicted.
    person is carrying her meal to her table, as a result => he will be full.
    {}, as a result => '''.format(event)
    print("EVENT: ",event)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
    intents = []
    for i in range(10):
        
        generated_ids = model.generate(input_ids, do_sample=True, max_length=160)
        intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        #print("1    --->",intent)
        intent = intent[0].split(event)[1].replace("\n",".").split(".")[0].split("=>")
        #print(intent)
        if len(intent) > 1:
            intent = intent[1]
        else:
            continue
        intents.append(intent.lstrip())
        print("2    --->",intent.lstrip())
    events_and_intents.append((event, intents))
print(events_and_intents)

# %%
set_seed(64)
prompt = '''
    Event: person is sitting at the bar in a sexy dress and waiting for someone. Similar events: man waiting for the train, lonely woman in pajamas eating chocolate.
    Event: person is facing the crowd while holding a microphone. Similar events: man making a presentation to men in suits, the singer performs on stage.
    Event: person is an officer that has handcuffed a citizen to himself. Similar events: female officer wearing a leather jacket and armed with a submachine gun, military man arresting a member of the public.
    Event: person is crossing the busy street and watching a taxi speed off. Similar events:
'''
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.cuda()
intents = []
for i in range(5):
    
    generated_ids = model.generate(input_ids, do_sample=True, max_length=180)
    intent = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    #print("1    --->",intent)
    intent = intent[0].replace("\n",".").split("Event:")[-1]
    print("Debug:",intent)
    # if len(intent) > 1:
    #     intent = intent[1]
    # else:
    #     continue
    # intents.append(intent.lstrip())
    # print("2    --->",intent.lstrip())
